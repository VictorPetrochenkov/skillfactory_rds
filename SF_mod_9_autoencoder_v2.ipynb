# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorPetrochenkov/skillfactory_rds/blob/master/SF_mod_9_autoencoder_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q tensorflow==2.1

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.models as M

print(tf.__version__)
# Out:
# 2.1.0

# %%
# Проверяем что у нас работает GPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#GPU count and name
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-ed6e77ce-a87c-4ea4-cd55-51f60cb01817)

# %% [markdown]
# ## Load and preprocess MNIST dataset

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.mnist.load_data()

train_x = train_x.reshape(-1, 28, 28, 1).astype(np.float32) / 255.
test_x = test_x.reshape(-1, 28, 28, 1).astype(np.float32) / 255.

print(train_x.shape, train_x.dtype)
print(test_x.shape, test_x.dtype)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28, 1) float32
# (10000, 28, 28, 1) float32

# %% [markdown]
# ## Draw MNIST examples

# %%
def plot_digits(samples):
    fig = plt.figure(figsize=(10, 6))
    num = samples.shape[0]
    for j in range(num):
        ax = fig.add_subplot(4, 8, j+1)
        ax.imshow(samples[j,:,:,0], cmap='gray')
        plt.xticks([]), plt.yticks([])
    plt.show()
    
plot_digits(train_x[:32, ...])

# %% [markdown]
# ## Create Autoencoder model: Encoder and Decoder

# %%
train_x.shape[1:]
# Out:
# (28, 28, 1)

# %%
encoder = M.Sequential([
    #L.ZeroPadding2D((2, 2)),
    L.Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=train_x.shape[1:]),
    L.MaxPooling2D((2, 2), padding='same'),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.MaxPooling2D((2, 2), padding='same'),
    L.Conv2D(8, (3, 3), strides=(2,2), activation='relu', padding='same'),
    # Flatten encoding for visualization
    L.Flatten(),
    L.Reshape((4, 4, 8)),
])

decoder = M.Sequential([
    L.Conv2D(8, (3, 3), activation='relu', padding='same', input_shape=(4, 4, 8)),
    L.UpSampling2D((2, 2)),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.UpSampling2D((2, 2)),
    L.Conv2D(8, (3, 3), padding='same', activation='relu'),
    L.UpSampling2D((2, 2)),
    L.Conv2D(1, (3, 3), padding='same', activation='sigmoid'),
    L.Cropping2D((2, 2))
])

autoencoder = M.Sequential([encoder, decoder])

autoencoder.compile(optimizer='RMSprop', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 4, 4, 8)           1904
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 28, 28, 1)         1825
# =================================================================
# Total params: 3,729
# Trainable params: 3,729
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Autoencoder training

# %%
NUM_EPOCHS = 25
BATCH_SIZE = 128

# %%
autoencoder.fit(train_x, train_x,
                epochs=NUM_EPOCHS,
                batch_size=BATCH_SIZE,
                shuffle=True,
                validation_data=(test_x, test_x))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.0448 - val_loss: 0.0315
# Epoch 2/25
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0267 - val_loss: 0.0247
# Epoch 3/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0226 - val_loss: 0.0207
# Epoch 4/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0201 - val_loss: 0.0193
# Epoch 5/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0185 - val_loss: 0.0169
# Epoch 6/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0173 - val_loss: 0.0162
# Epoch 7/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0163 - val_loss: 0.0147
# Epoch 8/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0156 - val_loss: 0.0158
# Epoch 9/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0150 - val_loss: 0.0140
# Epoch 10/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0144 - val_loss: 0.0153
# Epoch 11/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0139 - val_loss: 0.0138
# Epoch 12/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0135 - val_loss: 0.0132
# Epoch 13/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0131 - val_loss: 0.0132
# Epoch 14/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0128 - val_loss: 0.0119
# Epoch 15/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0124 - val_loss: 0.0119
# Epoch 16/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0122 - val_loss: 0.0113
# Epoch 17/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0119 - val_loss: 0.0108
# Epoch 18/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0117 - val_loss: 0.0115
# Epoch 19/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0115 - val_loss: 0.0108
# Epoch 20/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0113 - val_loss: 0.0109
# Epoch 21/25
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.0112 - val_loss: 0.0110
# Epoch 22/25
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.0110 - val_loss: 0.0105
# Epoch 23/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0109 - val_loss: 0.0103
# Epoch 24/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0107 - val_loss: 0.0106
# Epoch 25/25
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0106 - val_loss: 0.0108

# %% [markdown]
# ## Autoencoder inference test

# %%
text_x_pred = autoencoder.predict(test_x[0:8])

plot_digits(test_x[0:8])
plot_digits(text_x_pred)

# %% [markdown]
# Посмотрим как происходит транформация по этапам

# %%
num_images = 10
random_test_images = np.random.randint(test_x.shape[0], size=num_images)

encoded_imgs = encoder.predict(test_x)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(test_x[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(16, 8))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Decoder inference test: random inputs

# %%
plot_digits(decoder.predict(np.random.rand(8, 4, 4, 8) * 5))

# %% [markdown]
# ## Prepare noisy dataset (for Denoising AE)

# %%
def add_noise(x):
    return np.clip(x + 0.5 + 0.5*np.random.randn(*x.shape), 0, 1)

train_x_noise = add_noise(train_x)
test_x_noise = add_noise(test_x)

plot_digits(train_x_noise[:8])

# %% [markdown]
# ## Denoising Autoencoder training

# %%
NUM_EPOCHS = 25
BATCH_SIZE = 128

autoencoder.fit(train_x_noise, train_x,
                epochs=NUM_EPOCHS,
                batch_size=BATCH_SIZE,
                shuffle=True,
                validation_data=(test_x_noise, test_x))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0341 - val_loss: 0.0279
# Epoch 2/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0272 - val_loss: 0.0252
# Epoch 3/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0250 - val_loss: 0.0246
# Epoch 4/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0238 - val_loss: 0.0228
# Epoch 5/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0230 - val_loss: 0.0217
# Epoch 6/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0225 - val_loss: 0.0215
# Epoch 7/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0221 - val_loss: 0.0221
# Epoch 8/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0218 - val_loss: 0.0205
# Epoch 9/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0215 - val_loss: 0.0203
# Epoch 10/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0212 - val_loss: 0.0212
# Epoch 11/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0210 - val_loss: 0.0210
# Epoch 12/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0209 - val_loss: 0.0200
# Epoch 13/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0207 - val_loss: 0.0199
# Epoch 14/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0206 - val_loss: 0.0234
# Epoch 15/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0205 - val_loss: 0.0199
# Epoch 16/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0204 - val_loss: 0.0195
# Epoch 17/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0203 - val_loss: 0.0192
# Epoch 18/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0201 - val_loss: 0.0211
# Epoch 19/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0201 - val_loss: 0.0195
# Epoch 20/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0200 - val_loss: 0.0195
# Epoch 21/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0199 - val_loss: 0.0192
# Epoch 22/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0199 - val_loss: 0.0192
# Epoch 23/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0198 - val_loss: 0.0202
# Epoch 24/25
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0197 - val_loss: 0.0200
# Epoch 25/25
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0197 - val_loss: 0.0203

# %% [markdown]
# ## Denoising Autoencoder inference test

# %%
text_x_pred = autoencoder.predict(test_x_noise[0:8])

plot_digits(test_x_noise[0:8])
plot_digits(text_x_pred)
